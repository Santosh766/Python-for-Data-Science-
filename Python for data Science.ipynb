# %% [markdown]
# #     PANDAS TUTORIAL EDUREKA

# %%
#one dimensional lebel 
# columns in excell
import pandas as pd #alias as pd
import numpy as np

# %%
s = pd.Series([1,2,3,4,5,np.nan,7,8,9,10])  # values are passed inside a list
print(s)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     NaN
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float64

# %%
a = pd.Series([1,2,3,4,5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = pd.date_range('20210301',periods = 15)

# %%
d
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08',
#                '2021-03-09', '2021-03-10', '2021-03-11', '2021-03-12',
#                '2021-03-13', '2021-03-14', '2021-03-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df1 = pd.DataFrame(np.random.randn(15,4),index = d,columns = ['A','B','C','D'])

# random.randn (10,4)   10 raws and 4 columns random values using numpy array

# %%
df1
# Out:
#                    A         B         C         D
# 2021-03-01 -0.203314  0.876721  0.996922  2.761105
# 2021-03-02 -0.229583 -2.375438  0.358591 -0.822248
# 2021-03-03 -1.764923  0.263387 -1.429561 -0.234613
# 2021-03-04 -0.823955 -1.411426  2.417624 -0.656870
# 2021-03-05  0.141145 -0.420817  0.008908  0.969712
# 2021-03-06  0.442426  1.166061  0.883176  0.550598
# 2021-03-07  0.257622  0.174925 -0.848369 -1.065663
# 2021-03-08  0.628842  0.344108  1.242728  1.098529
# 2021-03-09 -0.440990  0.255410  0.648374 -1.050358
# 2021-03-10  1.757449 -1.305114  1.043813  0.682517
# 2021-03-11  1.190394  0.535335  0.258702  1.157859
# 2021-03-12  0.632005  0.670587  1.442963  0.802763
# 2021-03-13 -0.298194  0.170828  0.600837  2.075883
# 2021-03-14  1.030404 -1.291774  0.547681  0.693957
# 2021-03-15  0.173161 -0.350013 -0.175242 -1.302231

# %%
# data entry using the dictionary & numpy array
df = pd.DataFrame({'A':[1,2,3,4],
                   'B':pd.Timestamp('20210301'),
                   'C':pd.Series(1, index= list(range(4)), dtype= 'float32'),
                   'D':np.array([5]*4,dtype = 'int32'),
                   'E':pd.Categorical(['true','false','true','false']),
                  'F':np.array(['Edureka']*4)})

# %%
df
# Out:
#    A          B    C  D      E        F
# 0  1 2021-03-01  1.0  5   true  Edureka
# 1  2 2021-03-01  1.0  5  false  Edureka
# 2  3 2021-03-01  1.0  5   true  Edureka
# 3  4 2021-03-01  1.0  5  false  Edureka

# %%
pd.Timestamp('20210301')
# Out:
# Timestamp('2021-03-01 00:00:00')

# %%
df.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # HOW TO VIEW DATA?

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679

# %%
df1.tail(1)
# Out:
#                    A         B         C         D
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
df1.index   # all the raws or we can say index
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08',
#                '2021-03-09', '2021-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df1.columns  # all the vertical columns headings
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# view data as numpy array
df1.to_numpy()
# Out:
# array([[ 0.97533834,  0.48496971, -0.44840957, -1.43605563],
#        [ 0.86956541,  0.89855665, -1.07525092,  0.53135453],
#        [-0.65899566,  2.63412732,  0.52993565, -0.4970708 ],
#        [ 0.32985109, -0.68600418,  0.03594023,  0.32011151],
#        [-0.55718109, -0.02762712, -0.17217641,  0.56267904],
#        [-2.31386071,  0.7648672 ,  0.66629136, -1.07646445],
#        [ 1.02533644, -1.24829925,  0.16354569, -0.43693576],
#        [ 0.7536747 , -0.17131025, -0.60096876, -0.6420814 ],
#        [ 0.77131574, -0.71531812, -1.26475531,  0.24453406],
#        [ 1.28214374,  1.09555268,  0.90305367,  1.08228238]])

# %%
df1.describe() # all possible calculation
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.247719   0.302951  -0.126279  -0.134765
# std     1.113524   1.126417   0.726980   0.804310
# min    -2.313861  -1.248299  -1.264755  -1.436056
# 25%    -0.335423  -0.557331  -0.562829  -0.605829
# 50%     0.762495   0.228671  -0.068118  -0.096201
# 75%     0.948895   0.865134   0.438338   0.478544
# max     1.282144   2.634127   0.903054   1.082282

# %%
#sorting by axis

df1.sort_index(axis=1,ascending=True)
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
df1.sort_index(axis=0,ascending=False)
# Out:
#                    A         B         C         D
# 2021-03-10  1.282144  1.095553  0.903054  1.082282
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056

# %%
df1.sort_values(by='C')    # by default in sortsin ascending order
# Out:
#                    A         B         C         D
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
df1['C']
# Out:
# 2021-03-01   -0.448410
# 2021-03-02   -1.075251
# 2021-03-03    0.529936
# 2021-03-04    0.035940
# 2021-03-05   -0.172176
# 2021-03-06    0.666291
# 2021-03-07    0.163546
# 2021-03-08   -0.600969
# 2021-03-09   -1.264755
# 2021-03-10    0.903054
# Freq: D, Name: C, dtype: float64

# %%
df1[0:6]     #here 6th raw is excluded
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464

# %%
df.loc[:,['A','B']]
# Out:
#    A          B
# 0  1 2021-03-01
# 1  2 2021-03-01
# 2  3 2021-03-01
# 3  4 2021-03-01

# %%
df1.loc[:]
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
df1.loc['20210301':'20210304']  # here again index 3 is excluded
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112

# %%
df1.loc['20210301':'20210306',['D','C']]
# Out:
#                    D         C
# 2021-03-01 -1.436056 -0.448410
# 2021-03-02  0.531355 -1.075251
# 2021-03-03 -0.497071  0.529936
# 2021-03-04  0.320112  0.035940
# 2021-03-05  0.562679 -0.172176
# 2021-03-06 -1.076464  0.666291

# %%
df1.iloc[3]
# Out:
# A    0.329851
# B   -0.686004
# C    0.035940
# D    0.320112
# Name: 2021-03-04 00:00:00, dtype: float64

# %%
df1.loc[d[0],'C']
# Out:
# -0.4484095659393269

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679

# %%
df1.iloc[3:5,0:3]
# Out:
#                    A         B         C
# 2021-03-04  0.329851 -0.686004  0.035940
# 2021-03-05 -0.557181 -0.027627 -0.172176

# %%
df[df['A']>2]   # Needed in case of applying to the dataframe
# Out:
#    A          B    C  D      E        F
# 2  3 2021-03-01  1.0  5   true  Edureka
# 3  4 2021-03-01  1.0  5  false  Edureka

# %% [markdown]
# # HOW TO HANDLE MISSING DATA?

# %%
df2=df1.reindex(index=d[0:4],columns = list(df1.columns)+['E'])
df2
# Out:
#                    A         B         C         D   E
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056 NaN
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355 NaN
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071 NaN
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112 NaN

# %%
df1
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
df2.loc[d[0]:d[2],'E']=None
df2
# Out:
#                    A         B         C         D    E
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056  NaN
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355  NaN
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071  NaN
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112  0.0

# %%
df2.isnull()
# Out:
#                 A      B      C      D      E
# 2021-03-01  False  False  False  False   True
# 2021-03-02  False  False  False  False   True
# 2021-03-03  False  False  False  False   True
# 2021-03-04  False  False  False  False  False

# %%
df2.dropna()
# Out:
#                    A         B        C         D    E
# 2021-03-04  0.329851 -0.686004  0.03594  0.320112  0.0

# %%
df2
# Out:
#                    A         B         C         D    E
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056  NaN
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355  NaN
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071  NaN
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112  0.0

# %%
df2.fillna(value = 2)
# Out:
#                    A         B         C         D    E
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056  2.0
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355  2.0
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071  2.0
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112  0.0

# %%
df2
# Out:
#                    A         B         C         D    E
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056  NaN
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355  NaN
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071  NaN
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112  0.0

# %%
pd.isna(df2)
# Out:
#                 A      B      C      D      E
# 2021-03-01  False  False  False  False   True
# 2021-03-02  False  False  False  False   True
# 2021-03-03  False  False  False  False   True
# 2021-03-04  False  False  False  False  False

# %% [markdown]
# # PANDAS OPERATIONS

# %%
df1 =
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
d    # datetime
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08',
#                '2021-03-09', '2021-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df1.mean(1)
# Out:
# 2021-03-01   -0.106039
# 2021-03-02    0.306056
# 2021-03-03    0.501999
# 2021-03-04   -0.000025
# 2021-03-05   -0.048576
# 2021-03-06   -0.489792
# 2021-03-07   -0.124088
# 2021-03-08   -0.165171
# 2021-03-09   -0.241056
# 2021-03-10    1.090758
# Freq: D, dtype: float64

# %%
pd.Series([1,2,3,np.nan,4,5,6,7,8,9],index= d)
# Out:
# 2021-03-01    1.0
# 2021-03-02    2.0
# 2021-03-03    3.0
# 2021-03-04    NaN
# 2021-03-05    4.0
# 2021-03-06    5.0
# 2021-03-07    6.0
# 2021-03-08    7.0
# 2021-03-09    8.0
# 2021-03-10    9.0
# Freq: D, dtype: float64

# %%
df1.sub(s, axis= 'index')
# Out:
#                       A   B   C   D
# 2021-03-01 00:00:00 NaN NaN NaN NaN
# 2021-03-02 00:00:00 NaN NaN NaN NaN
# 2021-03-03 00:00:00 NaN NaN NaN NaN
# 2021-03-04 00:00:00 NaN NaN NaN NaN
# 2021-03-05 00:00:00 NaN NaN NaN NaN
# 2021-03-06 00:00:00 NaN NaN NaN NaN
# 2021-03-07 00:00:00 NaN NaN NaN NaN
# 2021-03-08 00:00:00 NaN NaN NaN NaN
# 2021-03-09 00:00:00 NaN NaN NaN NaN
# 2021-03-10 00:00:00 NaN NaN NaN NaN
# 0                   NaN NaN NaN NaN
# 1                   NaN NaN NaN NaN
# 2                   NaN NaN NaN NaN
# 3                   NaN NaN NaN NaN
# 4                   NaN NaN NaN NaN
# 5                   NaN NaN NaN NaN
# 6                   NaN NaN NaN NaN
# 7                   NaN NaN NaN NaN
# 8                   NaN NaN NaN NaN
# 9                   NaN NaN NaN NaN

# %%
df1
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  0.869565  0.898557 -1.075251  0.531355
# 2021-03-03 -0.658996  2.634127  0.529936 -0.497071
# 2021-03-04  0.329851 -0.686004  0.035940  0.320112
# 2021-03-05 -0.557181 -0.027627 -0.172176  0.562679
# 2021-03-06 -2.313861  0.764867  0.666291 -1.076464
# 2021-03-07  1.025336 -1.248299  0.163546 -0.436936
# 2021-03-08  0.753675 -0.171310 -0.600969 -0.642081
# 2021-03-09  0.771316 -0.715318 -1.264755  0.244534
# 2021-03-10  1.282144  1.095553  0.903054  1.082282

# %%
df1.apply(np.cumsum)   # it basically add its all upper raws values and print it in its own shell.
# Out:
#                    A         B         C         D
# 2021-03-01  0.975338  0.484970 -0.448410 -1.436056
# 2021-03-02  1.844904  1.383526 -1.523660 -0.904701
# 2021-03-03  1.185908  4.017654 -0.993725 -1.401772
# 2021-03-04  1.515759  3.331650 -0.957785 -1.081660
# 2021-03-05  0.958578  3.304022 -1.129961 -0.518981
# 2021-03-06 -1.355283  4.068890 -0.463670 -1.595446
# 2021-03-07 -0.329946  2.820590 -0.300124 -2.032382
# 2021-03-08  0.423729  2.649280 -0.901093 -2.674463
# 2021-03-09  1.195044  1.933962 -2.165848 -2.429929
# 2021-03-10  2.477188  3.029515 -1.262794 -1.347647

# %%
df1.apply(lambda x:  x.max()-x.min())   #lambda function is used here for mathematical operation
# Out:
# A    3.596004
# B    3.882427
# C    2.167809
# D    2.518338
# dtype: float64

# %%
s  # series that we have initialised
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     NaN
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float64

# %%
s.value_counts()
# Out:
# 3.0     1
# 7.0     1
# 10.0    1
# 4.0     1
# 8.0     1
# 2.0     1
# 9.0     1
# 5.0     1
# 1.0     1
# dtype: int64

# %%
df1.value_counts()
# Out:
# A          B          C          D
# -2.313861   0.764867   0.666291  -1.076464    1
# -0.658996   2.634127   0.529936  -0.497071    1
# -0.557181  -0.027627  -0.172176   0.562679    1
#  0.329851  -0.686004   0.035940   0.320112    1
#  0.753675  -0.171310  -0.600969  -0.642081    1
#  0.771316  -0.715318  -1.264755   0.244534    1
#  0.869565   0.898557  -1.075251   0.531355    1
#  0.975338   0.484970  -0.448410  -1.436056    1
#  1.025336  -1.248299   0.163546  -0.436936    1
#  1.282144   1.095553   0.903054   1.082282    1
# dtype: int64

# %%
s = pd.Series(['edureka','python','jupiter',np.nan,'football','worls'])

# %%
s
# Out:
# 0     edureka
# 1      python
# 2     jupiter
# 3         NaN
# 4    football
# 5       worls
# dtype: object

# %%
s.str.upper()   #capital letter
# Out:
# 0     EDUREKA
# 1      PYTHON
# 2     JUPITER
# 3         NaN
# 4    FOOTBALL
# 5       WORLS
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.419439  0.186040 -0.657440 -0.223124
# 1 -0.665290  1.017236  0.329115  0.485927
# 2 -1.005806  0.026968  0.129544  1.393772
# 3 -1.218054  0.595804  0.507066 -0.473162
# 4 -0.247940 -0.415952  0.146042  0.722354
# 5 -0.738165  0.245378 -0.912388 -0.745606
# 6 -0.777963  0.271812  0.824016  0.254121
# 7 -0.073549  1.581819  0.453154  1.964800
# 8 -1.335827  0.583706 -1.261749  0.197262
# 9 -0.399153  0.297937  0.170428  0.263203

# %%
df.iloc[:]
# Out:
#           0         1         2         3
# 0 -0.419439  0.186040 -0.657440 -0.223124
# 1 -0.665290  1.017236  0.329115  0.485927
# 2 -1.005806  0.026968  0.129544  1.393772
# 3 -1.218054  0.595804  0.507066 -0.473162
# 4 -0.247940 -0.415952  0.146042  0.722354
# 5 -0.738165  0.245378 -0.912388 -0.745606
# 6 -0.777963  0.271812  0.824016  0.254121
# 7 -0.073549  1.581819  0.453154  1.964800
# 8 -1.335827  0.583706 -1.261749  0.197262
# 9 -0.399153  0.297937  0.170428  0.263203

# %%
df2 = [df[:3],df[3:7],df[7:8]]

# %%
df2
# Out:
# [          0         1         2         3
#  0 -0.419439  0.186040 -0.657440 -0.223124
#  1 -0.665290  1.017236  0.329115  0.485927
#  2 -1.005806  0.026968  0.129544  1.393772,
#            0         1         2         3
#  3 -1.218054  0.595804  0.507066 -0.473162
#  4 -0.247940 -0.415952  0.146042  0.722354
#  5 -0.738165  0.245378 -0.912388 -0.745606
#  6 -0.777963  0.271812  0.824016  0.254121,
#            0         1         2       3
#  7 -0.073549  1.581819  0.453154  1.9648]

# %%
pd.concat(df2)    # used to concat several parts of dataframe
# Out:
#           0         1         2         3
# 0 -0.419439  0.186040 -0.657440 -0.223124
# 1 -0.665290  1.017236  0.329115  0.485927
# 2 -1.005806  0.026968  0.129544  1.393772
# 3 -1.218054  0.595804  0.507066 -0.473162
# 4 -0.247940 -0.415952  0.146042  0.722354
# 5 -0.738165  0.245378 -0.912388 -0.745606
# 6 -0.777963  0.271812  0.824016  0.254121
# 7 -0.073549  1.581819  0.453154  1.964800

# %%
# join function

# %%
left = pd.DataFrame({'A':[1,2],'B':[3,4]})

# %%
right =pd.DataFrame({'A':[3,2],'C':[4,5]})

# %%
left
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
right
# Out:
#    A  C
# 0  3  4
# 1  2  5

# %%
pd.merge(left,right)
# Out:
#    A  B  C
# 0  2  4  5

# %%
df
# Out:
#           0         1         2         3
# 0 -0.419439  0.186040 -0.657440 -0.223124
# 1 -0.665290  1.017236  0.329115  0.485927
# 2 -1.005806  0.026968  0.129544  1.393772
# 3 -1.218054  0.595804  0.507066 -0.473162
# 4 -0.247940 -0.415952  0.146042  0.722354
# 5 -0.738165  0.245378 -0.912388 -0.745606
# 6 -0.777963  0.271812  0.824016  0.254121
# 7 -0.073549  1.581819  0.453154  1.964800
# 8 -1.335827  0.583706 -1.261749  0.197262
# 9 -0.399153  0.297937  0.170428  0.263203

# %%
df.groupby([1]).sum()
# Out:
#                   0         2         3
# 1
# -0.415952 -0.247940  0.146042  0.722354
#  0.026968 -1.005806  0.129544  1.393772
#  0.186040 -0.419439 -0.657440 -0.223124
#  0.245378 -0.738165 -0.912388 -0.745606
#  0.271812 -0.777963  0.824016  0.254121
#  0.297937 -0.399153  0.170428  0.263203
#  0.583706 -1.335827 -1.261749  0.197262
#  0.595804 -1.218054  0.507066 -0.473162
#  1.017236 -0.665290  0.329115  0.485927
#  1.581819 -0.073549  0.453154  1.964800

# %%
col = ['a','b','c']
data = ['santosh','rajesh','jay']
df2 = pd.DataFrame(nindex=col,columns = data)

# %%
df2
# Out:
#   santosh rajesh  jay
# a     NaN    NaN  NaN
# b     NaN    NaN  NaN
# c     NaN    NaN  NaN

# %%
df = pd.DataFrame({'Vehicle':["car",'truck','scooty','bike','car'],
                   'B':pd.Timestamp('20210301'),
                   'C':pd.Series(2, index= list(range(5)), dtype= 'float32'),
                   'D':np.array([1000]*5,dtype = 'int32'),
                   'type of fuel':pd.Categorical(['petrol','diesel','petrol','petrol','petrol']),
                  'price':np.array([30000]*5)})

# %%
df
# Out:
#   Vehicle          B    C     D type of fuel  price
# 0     car 2021-03-01  2.0  1000       petrol  30000
# 1   truck 2021-03-01  2.0  1000       diesel  30000
# 2  scooty 2021-03-01  2.0  1000       petrol  30000
# 3    bike 2021-03-01  2.0  1000       petrol  30000
# 4     car 2021-03-01  2.0  1000       petrol  30000

# %%
df.groupby('Vehicle').sum()    # first it  will do grouping and then it will add the values according to number of vehicles
# Out:
#            C     D  price
# Vehicle
# bike     2.0  1000  30000
# car      4.0  2000  60000
# scooty   2.0  1000  30000
# truck    2.0  1000  30000

# %% [markdown]
# # MERGE, GROUP & RESHAPING DATA

# %%
# stack and pivot table

# %%
my_tuple = list(zip(*[[1,2,3,4,5,17,18,19], [11,12,13,6,7,8,9,10]]))

# %%
index = pd.MultiIndex.from_tuples(my_tuple, names= ['First','Second'])

# %%
df = pd.DataFrame(np.random.randn(8,2), index = index,columns=['A','B'])

# %%
df
# Out:
#                      A         B
# First Second
# 1     11     -1.288427  0.551834
# 2     12     -0.120260 -0.040467
# 3     13     -1.426325  0.763721
# 4     6       1.761182 -0.588990
# 5     7      -0.626441  1.311599
# 17    8      -0.270016 -2.048834
# 18    9       1.453768  0.155073
# 19    10      1.625763  0.905035

# %%
a = df.stack()

# %%
a
# Out:
# First  Second
# 1      11      A   -1.288427
#                B    0.551834
# 2      12      A   -0.120260
#                B   -0.040467
# 3      13      A   -1.426325
#                B    0.763721
# 4      6       A    1.761182
#                B   -0.588990
# 5      7       A   -0.626441
#                B    1.311599
# 17     8       A   -0.270016
#                B   -2.048834
# 18     9       A    1.453768
#                B    0.155073
# 19     10      A    1.625763
#                B    0.905035
# dtype: float64

# %%
a.unstack()
# Out:
#                      A         B
# First Second
# 1     11     -1.288427  0.551834
# 2     12     -0.120260 -0.040467
# 3     13     -1.426325  0.763721
# 4     6       1.761182 -0.588990
# 5     7      -0.626441  1.311599
# 17    8      -0.270016 -2.048834
# 18    9       1.453768  0.155073
# 19    10      1.625763  0.905035

# %%
df = pd.DataFrame({'A':['a','b','c','d']*3,
                   'B':["A","B","C"]*4,
                   'C':['P','P','P','Q','Q','Q']*2,
                   'D': np.random.randn(12),
                   'E': np.random.randn(12)
                  })

# %%
df
# Out:
#     A  B  C         D         E
# 0   a  A  P  1.024703  0.065258
# 1   b  B  P  0.592220 -1.595017
# 2   c  C  P  0.171855 -0.358109
# 3   d  A  Q  0.278931  0.762709
# 4   a  B  Q -0.134713 -0.310623
# 5   b  C  Q -1.438765 -0.908839
# 6   c  A  P -2.010557  0.062049
# 7   d  B  P  0.006633 -0.564713
# 8   a  C  P -0.297701  1.660040
# 9   b  A  Q  1.413628 -0.681131
# 10  c  B  Q  0.116470 -0.858625
# 11  d  C  Q  0.279119  0.182151

# %%
pd.pivot_table(df, values = ['E','D'], index =['A','B'])
# Out:
#             D         E
# A B
# a A  1.024703  0.065258
#   B -0.134713 -0.310623
#   C -0.297701  1.660040
# b A  1.413628 -0.681131
#   B  0.592220 -1.595017
#   C -1.438765 -0.908839
# c A -2.010557  0.062049
#   B  0.116470 -0.858625
#   C  0.171855 -0.358109
# d A  0.278931  0.762709
#   B  0.006633 -0.564713
#   C  0.279119  0.182151

# %% [markdown]
# # TIME SERIES AND CATEGORICAL DATA

# %%
dates = pd.date_range('3/3/2021', periods = 100, freq = 'S')

# %%
dates
# Out:
# DatetimeIndex(['2021-03-03 00:00:00', '2021-03-03 00:00:01',
#                '2021-03-03 00:00:02', '2021-03-03 00:00:03',
#                '2021-03-03 00:00:04', '2021-03-03 00:00:05',
#                '2021-03-03 00:00:06', '2021-03-03 00:00:07',
#                '2021-03-03 00:00:08', '2021-03-03 00:00:09',
#                '2021-03-03 00:00:10', '2021-03-03 00:00:11',
#                '2021-03-03 00:00:12', '2021-03-03 00:00:13',
#                '2021-03-03 00:00:14', '2021-03-03 00:00:15',
#                '2021-03-03 00:00:16', '2021-03-03 00:00:17',
#                '2021-03-03 00:00:18', '2021-03-03 00:00:19',
#                '2021-03-03 00:00:20', '2021-03-03 00:00:21',
#                '2021-03-03 00:00:22', '2021-03-03 00:00:23',
#                '2021-03-03 00:00:24', '2021-03-03 00:00:25',
#                '2021-03-03 00:00:26', '2021-03-03 00:00:27',
#                '2021-03-03 00:00:28', '2021-03-03 00:00:29',
# ...

# %%
ts = pd.Series(np.random.randint(0,500,len(dates)),index = dates) # randint gives random integer values ranging from 0 to 500

# %%
ts
# Out:
# 2021-03-03 00:00:00    379
# 2021-03-03 00:00:01    377
# 2021-03-03 00:00:02    103
# 2021-03-03 00:00:03    258
# 2021-03-03 00:00:04    327
#                       ...
# 2021-03-03 00:01:35    204
# 2021-03-03 00:01:36    375
# 2021-03-03 00:01:37    395
# 2021-03-03 00:01:38    183
# 2021-03-03 00:01:39    321
# Freq: S, Length: 100, dtype: int32

# %%
ts.resample("5min")

# %%
ts.resample('5min').sum()
# Out:
# 2021-03-03    26279
# Freq: 5T, dtype: int32

# %%
dates = pd.date_range('3/3/2021 00:00', periods = 100, freq = 'S')

# %%
dates
# Out:
# DatetimeIndex(['2021-03-03 00:00:00', '2021-03-03 00:00:01',
#                '2021-03-03 00:00:02', '2021-03-03 00:00:03',
#                '2021-03-03 00:00:04', '2021-03-03 00:00:05',
#                '2021-03-03 00:00:06', '2021-03-03 00:00:07',
#                '2021-03-03 00:00:08', '2021-03-03 00:00:09',
#                '2021-03-03 00:00:10', '2021-03-03 00:00:11',
#                '2021-03-03 00:00:12', '2021-03-03 00:00:13',
#                '2021-03-03 00:00:14', '2021-03-03 00:00:15',
#                '2021-03-03 00:00:16', '2021-03-03 00:00:17',
#                '2021-03-03 00:00:18', '2021-03-03 00:00:19',
#                '2021-03-03 00:00:20', '2021-03-03 00:00:21',
#                '2021-03-03 00:00:22', '2021-03-03 00:00:23',
#                '2021-03-03 00:00:24', '2021-03-03 00:00:25',
#                '2021-03-03 00:00:26', '2021-03-03 00:00:27',
#                '2021-03-03 00:00:28', '2021-03-03 00:00:29',
# ...

# %%
ts = pd.Series(np.random.randn(len(dates)),dates)

# %%
ts
# Out:
# 2021-03-03 00:00:00    1.442631
# 2021-03-03 00:00:01   -0.474943
# 2021-03-03 00:00:02    0.427215
# 2021-03-03 00:00:03    0.298809
# 2021-03-03 00:00:04    0.498824
#                          ...
# 2021-03-03 00:01:35   -0.174058
# 2021-03-03 00:01:36   -0.740278
# 2021-03-03 00:01:37   -0.364171
# 2021-03-03 00:01:38    0.112425
# 2021-03-03 00:01:39   -0.000617
# Freq: S, Length: 100, dtype: float64

# %%
# Timezone creation 

ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2021-03-03 00:00:00+00:00    1.442631
# 2021-03-03 00:00:01+00:00   -0.474943
# 2021-03-03 00:00:02+00:00    0.427215
# 2021-03-03 00:00:03+00:00    0.298809
# 2021-03-03 00:00:04+00:00    0.498824
#                                ...
# 2021-03-03 00:01:35+00:00   -0.174058
# 2021-03-03 00:01:36+00:00   -0.740278
# 2021-03-03 00:01:37+00:00   -0.364171
# 2021-03-03 00:01:38+00:00    0.112425
# 2021-03-03 00:01:39+00:00   -0.000617
# Freq: S, Length: 100, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2021-03-02 19:00:00-05:00    1.442631
# 2021-03-02 19:00:01-05:00   -0.474943
# 2021-03-02 19:00:02-05:00    0.427215
# 2021-03-02 19:00:03-05:00    0.298809
# 2021-03-02 19:00:04-05:00    0.498824
#                                ...
# 2021-03-02 19:01:35-05:00   -0.174058
# 2021-03-02 19:01:36-05:00   -0.740278
# 2021-03-02 19:01:37-05:00   -0.364171
# 2021-03-02 19:01:38-05:00    0.112425
# 2021-03-02 19:01:39-05:00   -0.000617
# Freq: S, Length: 100, dtype: float64

# %% [markdown]
# # categoricals

# %%
df = pd.DataFrame({'id': [1,2,3,4,5,6],
                  'grade':['a','b','c','d','e','f']})

# %%
df
# Out:
#    id grade
# 0   1     a
# 1   2     b
# 2   3     c
# 3   4     d
# 4   5     e
# 5   6     f

# %%
df['Grade']= df['grade'].astype('category')
df['Grade']
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# Name: Grade, dtype: category
# Categories (6, object): ['a', 'b', 'c', 'd', 'e', 'f']

# %%
df['Grade'].cat.categories= ['good', 'very good','excellant','weldon','Better', 'Best']

# %%
df["Grade"]
# Out:
# 0         good
# 1    very good
# 2    excellant
# 3       weldon
# 4       Better
# 5         Best
# Name: Grade, dtype: category
# Categories (6, object): ['good', 'very good', 'excellant', 'weldon', 'Better', 'Best']

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(500),index = pd.date_range('1/2/2020',periods = 500))

# %%
ts = ts.cumsum()   # cumsum returns cummilative sum of an array

# %%
ts.plot(color = 'r)
# Out:
# <AxesSubplot:>

# %%
ts
# Out:
# 2020-01-02    -0.918278
# 2020-01-03     1.036389
# 2020-01-04     2.643642
# 2020-01-05     3.203312
# 2020-01-06     1.902249
#                 ...
# 2021-05-11   -17.542363
# 2021-05-12   -17.771822
# 2021-05-13   -18.168428
# 2021-05-14   -19.127010
# 2021-05-15   -20.908869
# Freq: D, Length: 500, dtype: float64

# %%
ts.to_csv('PandaCSV.csv')

# %%
pd.read_csv(r"C:\Users\Santosh Paul\Desktop\jupiter notebook\Sample100.csv")
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...
